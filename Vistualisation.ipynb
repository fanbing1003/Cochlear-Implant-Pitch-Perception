# %%
import os

# %%
Octave = ['A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7']

# %%
filelist = os.listdir('Your CSV folder')
filelist = sorted(filelist)

# %%
Octave = ['A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8']

# %%
# Task1
import math
import matplotlib.pyplot as plt
plt.figure(figsize = (5, 5))
for i in filelist:
  path = '/content/drive/MyDrive/Colab Notebooks/IFN704/complete/' + i
  data = pd.read_csv(path)
  task1 = data[data['Task_Type'] == 'pitch_matching_double_aided']
  # Justify why
  x = [math.log(i/27.5, 2) for i in task1['Adj_Freq']]
  y = [math.log(i/27.5, 2) for i in task1['Target_Freq']]
  plt.plot([-0.5, 8.5], [-0.5, 8.5], color = 'black', zorder=0)
  #plt.scatter(x, y, label = i)
  plt.scatter(x, y)
  plt.title('Task 1: Double Aided')
  plt.xlabel('Adj')
  plt.ylabel('Ref')
  plt.xlim(-0.5, 7.5)
  plt.ylim(-0.5, 7.5)
  plt.xticks(range(0, 8), Octave)
  plt.yticks(range(0, 8), Octave)
  ax = plt.gca()
  ax.set_aspect('equal', adjustable='box')
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Task2
import math
for i in filelist[1:]:
  path = '/content/drive/MyDrive/Colab Notebooks/IFN704/complete/' + i
  data = pd.read_csv(path)
  task2 = data[data['Task_Type'] == 'pitch_matching_assess_aided']
  # Justify why
  x = [math.log(i/27.5, 2) for i in task2['Adj_Freq']]
  y = [math.log(i/27.5, 2) for i in task2['Target_Freq']]
  plt.plot([-0.5, 8.5], [-0.5, 8.5], color = 'black', zorder=0)
  plt.scatter(x, y)
  plt.xlabel('Adj')
  plt.ylabel('Ref')
  plt.xlim(-0.5, 8.5)
  plt.ylim(-0.5, 8.5)
  plt.xticks(range(0, 9), Octave)
  plt.yticks(range(0, 9), Octave)

# %%
# Task2
import math
for i in filelist[1:]:
  path = '/content/drive/MyDrive/Colab Notebooks/IFN704/complete/' + i
  data = pd.read_csv(path)
  task2 = data[data['Task_Type'] == 'pitch_matching_assess_aided']
  # Justify why
  plt.plot([-0.5, 8.5], [-0.5, 8.5], color = 'black', zorder=0)
  x = task2['Adj_Freq']
  y = task2['Target_Freq']
  plt.scatter(x, y)
  plt.plot([-100, 4000], [-100, 4000], color = 'black', zorder=0)
  plt.xlabel('Adj')
  plt.ylabel('Ref')

# %%
# Task3
import math
for i in filelist[1:]:
  path = '/content/drive/MyDrive/Colab Notebooks/IFN704/complete/' + i
  data = pd.read_csv(path)
  task3 = data[data['Task_Type'] == 'pitch_matching_assess_unaided']
  # Justify why
  x = [math.log(i/27.5, 2) for i in task3['Adj_Freq']]
  y = [math.log(i/27.5, 2) for i in task3['Target_Freq']]
  plt.plot([-0.5, 8.5], [-0.5, 8.5], color = 'black', zorder=0)
  plt.scatter(x, y)
  plt.xlabel('Adj')
  plt.ylabel('Ref')
  plt.xlim(-0.5, 8.5)
  plt.ylim(-0.5, 8.5)
  plt.xticks(range(0, 9), Octave)
  plt.yticks(range(0, 9), Octave)

# %%
# Task3
import math
for i in filelist[1:]:
  path = '/content/drive/MyDrive/Colab Notebooks/IFN704/complete/' + i
  data = pd.read_csv(path)
  task3 = data[data['Task_Type'] == 'pitch_matching_assess_unaided']
  # Justify why
  x = task3['Adj_Freq']
  y = task3['Target_Freq']
  plt.scatter(x, y)
  plt.plot([-100, 4000], [-100, 4000], color = 'black', zorder=0)
  plt.xlabel('Adj')
  plt.ylabel('Ref')

# %%
# Task4
for i in filelist[1:]:
  path = '/content/drive/MyDrive/Colab Notebooks/IFN704/complete/' + i
  data = pd.read_csv(path)
  task4 = data[data['Task_Type'] == 'pitch_matching_asssess_unaided_as_control']
  # Justify why
  x = [math.log(i/27.5, 2) for i in task4['Adj_Freq']]
  y = [math.log(i/27.5, 2) for i in task4['Target_Freq']]
  plt.plot([-0.5, 8.5], [-0.5, 8.5], color = 'black', zorder=0)
  plt.scatter(x, y)
  plt.xlabel('Adj')
  plt.ylabel('Ref')
  plt.xlim(-0.5, 8.5)
  plt.ylim(-0.5, 8.5)
  plt.xticks(range(0, 9), Octave)
  plt.yticks(range(0, 9), Octave)

# %%
# Task5
for i in filelist[1:]:
  path = '/content/drive/MyDrive/Colab Notebooks/IFN704/complete/' + i
  data = pd.read_csv(path)
  task5 = data[data['Task_Type'] == 'pitch_matching_both_ears_desktop_speaker']
  # Justify why
  x = [math.log(i/27.5, 2) for i in task5['Adj_Freq']]
  y = [math.log(i/27.5, 2) for i in task5['Target_Freq']]
  plt.plot([-0.5, 8.5], [-0.5, 8.5], color = 'black', zorder=0)
  plt.scatter(x, y)
  plt.xlabel('Adj')
  plt.ylabel('Ref')
  plt.xlim(-0.5, 8.5)
  plt.ylim(-0.5, 8.5)
  plt.xticks(range(0, 9), Octave)
  plt.yticks(range(0, 9), Octave)

# %%
Task1_data = pd.DataFrame()
Task2_data = pd.DataFrame()
Task3_data = pd.DataFrame()
Task4_data = pd.DataFrame()
Task5_data = pd.DataFrame()
for i in filelist:
  data = pd.read_csv(i)
  Task1_data = pd.concat([Task1_data, data[data['Task_Type'] == 'pitch_matching_double_aided']])
  Task2_data = pd.concat([Task1_data, data[data['Task_Type'] == 'pitch_matching_assess_aided']])
  Task3_data = pd.concat([Task1_data, data[data['Task_Type'] == 'pitch_matching_assess_unaided']])
  Task4_data = pd.concat([Task1_data, data[data['Task_Type'] == 'pitch_matching_asssess_unaided_as_control']])
  Task5_data = pd.concat([Task1_data, data[data['Task_Type'] == 'pitch_matching_both_ears_desktop_speaker']])
Task1_data.to_csv('Task1.csv')
Task2_data.to_csv('Task2.csv')
Task3_data.to_csv('Task3.csv')
Task4_data.to_csv('Task4.csv')
Task5_data.to_csv('Task5.csv')
